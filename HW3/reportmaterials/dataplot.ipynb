# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
scenario = [1,2,3,4,5,6]
data = [21141865*8/(50*1000000),42298363*8/(50*1000000),59628668*8/(50*1000000),60551341*8/(50*1000000),22077777*8/(50*1000000),18905092*8/(50*1000000)]

plt.plot(scenario, data)
plt.xlabel('Scenario')
plt.ylabel('nthroughput (Mbps)')
plt.title('Throughput vs Scenario')
plt.grid(True,'both')
plt.minorticks_on()
plt.show()
